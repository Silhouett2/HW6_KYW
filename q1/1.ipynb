# %%
pip install -U matplotlib

# %%
import matplotlib.pyplot as plt
import csv


print("*** Annual Tempurature Report for Seoul in 2022 ***")
f = open('korea.csv', 'r', encoding='cp949')
data = csv.reader(f, delimiter=',')

ycnr = []
place = []


# date = ''
# max = 0.0
# for row in data:
#     if row[-2] == ' ': # 공백값 있으면 skip
#         continue
#     elif row[-1] == ' ':
#         continue
#     else : 
#         try:
#             row[-1] = float(row[-1])
#             row[-2] = float(row[-2])
#             if max < row[-1] - row[-2]:
#                 max = row[-1] - row[-2]
#                 date = row[0]
#         except ValueError:
#             continue

date = ''
max = 0.0
place.append('')
for row in data:
    if row[-1] == ' ':
        continue
    else : 
        try:
            # print(type(float(row[-3])) == type(float))
            # print(type(float(row[-3])) == type(float))
            if type(float(row[-3])) == float : 
                ycnr.append(row[-3])
                place[0] = row[1]
        except ValueError:
            continue

print(ycnr)
print(place)
print(type(float))

ycnr.sort()

plt.plot(ycnr,)
plt.show


# for row in data:
#     if type(float(row[-1]) / 1.0) == type(float) :
#         print("dd")
# print("Day with the largest temperature variation:", date)
# print("maximum temperature difference :", round(max,2),"Celsius")
f.close()
# Out:
# *** Annual Tempurature Report for Seoul in 2022 ***
# ['-0.8', '-0.1', '7.7', '13.8', '18', '22.4', '25.9', '25.3', '21', '14', '9.6', '-1.4']
# ['전국']
# <class 'type'>
